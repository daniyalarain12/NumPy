# %% [markdown]
# # TYPES OF DATA
# - NUMERICAL DATA
# - IMAGE DATA
# - TEXT DATA

# %% [markdown]
# ## TYPES OF DATA SET
#
# ### PRIMARY DATASET
# - COLEECTED BY US
#
# ### SECONDARY DATASET
# - COLECTED BY SOMEONE ELSE WHICH IS AUTHENTICATED SOURCE
